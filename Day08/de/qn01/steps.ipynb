# %%
import pandas as pd
df = pd.read_csv('emp.csv')
df
# Out:
#     emp_id     name department           city   salary   join_date  \
# 0      101    Alice         IT       New York  72000.0  2019-06-15
# 1      102      Bob         HR         Boston  58000.0  2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0  2018-01-10
# 3      104    David         IT         Boston  75000.0  2017-03-25
# 4      105      Eve    Finance       New York  69000.0  2021-07-11
# 5      106    Frank         IT        Chicago      NaN  2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0  2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0  2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0  2018-05-29
# 9      110     John         HR       New York  59000.0  2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0  2019-02-20
# 11     112      Leo         IT         Boston  77000.0  2022-01-01
# 12     113     Mike  Marketing       New York  61000.0  2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0  2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0  2018-12-19
# 15     116     Paul         IT       New York  76000.0  2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN  2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0  2020-04-17
# 18     119    Steve         HR        Chicago  60000.0  2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0  2018-08-28
#
#     performance_score
# 0                  88
# 1                  77
# 2                  91
# 3                  85
# 4                  92
# 5                  80
# 6                  84
# 7                  88
# 8                  76
# 9                  79
# 10                 89
# 11                 95
# 12                 82
# 13                 80
# 14                 73
# 15                 90
# 16                 85
# 17                 88
# 18                 81
# 19                 87

# %%
df.columns
# Out:
# Index(['emp_id', 'name', 'department', 'city', 'salary', 'join_date',
#        'performance_score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# emp_id                 int64
# name                  object
# department            object
# city                  object
# salary               float64
# join_date             object
# performance_score      int64
# dtype: object

# %%
df.shape
# Out:
# (20, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   emp_id             20 non-null     int64
#  1   name               20 non-null     object
#  2   department         20 non-null     object
#  3   city               20 non-null     object
#  4   salary             18 non-null     float64
#  5   join_date          20 non-null     object
#  6   performance_score  20 non-null     int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#           emp_id        salary  performance_score
# count   20.00000     18.000000          20.000000
# mean   110.50000  67500.000000          84.500000
# std      5.91608   6582.061183           5.862459
# min    101.00000  58000.000000          73.000000
# 25%    105.75000  61000.000000          80.000000
# 50%    110.50000  68500.000000          85.000000
# 75%    115.25000  72750.000000          88.250000
# max    120.00000  77000.000000          95.000000

# %%
df.head()
# Out:
#    emp_id     name department      city   salary   join_date  \
# 0     101    Alice         IT  New York  72000.0  2019-06-15
# 1     102      Bob         HR    Boston  58000.0  2020-08-01
# 2     103  Charlie    Finance   Chicago  67000.0  2018-01-10
# 3     104    David         IT    Boston  75000.0  2017-03-25
# 4     105      Eve    Finance  New York  69000.0  2021-07-11
#
#    performance_score
# 0                 88
# 1                 77
# 2                 91
# 3                 85
# 4                 92

# %%
df.tail()
# Out:
#     emp_id    name department           city   salary   join_date  \
# 15     116    Paul         IT       New York  76000.0  2021-10-05
# 16     117   Quinn  Marketing         Boston      NaN  2019-05-30
# 17     118  Rachel    Finance  San Francisco  71000.0  2020-04-17
# 18     119   Steve         HR        Chicago  60000.0  2021-02-10
# 19     120    Tina         IT  San Francisco  72000.0  2018-08-28
#
#     performance_score
# 15                 90
# 16                 85
# 17                 88
# 18                 81
# 19                 87

# %%
df[5:10]
# Out:
#    emp_id   name department           city   salary   join_date  \
# 5     106  Frank         IT        Chicago      NaN  2019-11-04
# 6     107  Grace  Marketing  San Francisco  61000.0  2020-12-23
# 7     108  Heidi         IT  San Francisco  74000.0  2016-10-18
# 8     109    Ivy  Marketing         Boston  60000.0  2018-05-29
# 9     110   John         HR       New York  59000.0  2021-03-13
#
#    performance_score
# 5                 80
# 6                 84
# 7                 88
# 8                 76
# 9                 79

# %%
df[["name", "city"]]
# Out:
#        name           city
# 0     Alice       New York
# 1       Bob         Boston
# 2   Charlie        Chicago
# 3     David         Boston
# 4       Eve       New York
# 5     Frank        Chicago
# 6     Grace  San Francisco
# 7     Heidi  San Francisco
# 8       Ivy         Boston
# 9      John       New York
# 10     Kate        Chicago
# 11      Leo         Boston
# 12     Mike       New York
# 13     Nina  San Francisco
# 14     Owen        Chicago
# 15     Paul       New York
# 16    Quinn         Boston
# 17   Rachel  San Francisco
# 18    Steve        Chicago
# 19     Tina  San Francisco

# %%
df[5:10][["name", "city"]]
# Out:
#     name           city
# 5  Frank        Chicago
# 6  Grace  San Francisco
# 7  Heidi  San Francisco
# 8    Ivy         Boston
# 9   John       New York

# %%
df[(df["city"] == "Chicago")]
# Out:
#     emp_id     name department     city   salary   join_date  \
# 2      103  Charlie    Finance  Chicago  67000.0  2018-01-10
# 5      106    Frank         IT  Chicago      NaN  2019-11-04
# 10     111     Kate    Finance  Chicago  73000.0  2019-02-20
# 14     115     Owen    Finance  Chicago  68000.0  2018-12-19
# 18     119    Steve         HR  Chicago  60000.0  2021-02-10
#
#     performance_score
# 2                  91
# 5                  80
# 10                 89
# 14                 73
# 18                 81

# %%
df[(df["city"] == "Chicago") & (df["department"] == "Finance")]
# Out:
#     emp_id     name department     city   salary   join_date  \
# 2      103  Charlie    Finance  Chicago  67000.0  2018-01-10
# 10     111     Kate    Finance  Chicago  73000.0  2019-02-20
# 14     115     Owen    Finance  Chicago  68000.0  2018-12-19
#
#     performance_score
# 2                  91
# 10                 89
# 14                 73

# %%
df[(df["city"] == "Chicago") & (df["department"] == "Finance") & (df["salary"] < 70000)]
# Out:
#     emp_id     name department     city   salary   join_date  \
# 2      103  Charlie    Finance  Chicago  67000.0  2018-01-10
# 14     115     Owen    Finance  Chicago  68000.0  2018-12-19
#
#     performance_score
# 2                  91
# 14                 73

# %%
#check for data cleaning
df.isnull().sum()
# Out:
# emp_id               0
# name                 0
# department           0
# city                 0
# salary               2
# join_date            0
# performance_score    0
# dtype: int64

# %%
df['salary'].mean()
# Out:
# np.float64(67500.0)

# %%
df['salary'].fillna(df['salary'].mean())
# Out:
# 0     72000.0
# 1     58000.0
# 2     67000.0
# 3     75000.0
# 4     69000.0
# 5     67500.0
# 6     61000.0
# 7     74000.0
# 8     60000.0
# 9     59000.0
# 10    73000.0
# 11    77000.0
# 12    61000.0
# 13    62000.0
# 14    68000.0
# 15    76000.0
# 16    67500.0
# 17    71000.0
# 18    60000.0
# 19    72000.0
# Name: salary, dtype: float64

# %%
#check for data cleaning
df.isnull().sum()
# Out:
# emp_id               0
# name                 0
# department           0
# city                 0
# salary               2
# join_date            0
# performance_score    0
# dtype: int64

# %%
df.dropna()
# Out:
#     emp_id     name department           city   salary   join_date  \
# 0      101    Alice         IT       New York  72000.0  2019-06-15
# 1      102      Bob         HR         Boston  58000.0  2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0  2018-01-10
# 3      104    David         IT         Boston  75000.0  2017-03-25
# 4      105      Eve    Finance       New York  69000.0  2021-07-11
# 6      107    Grace  Marketing  San Francisco  61000.0  2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0  2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0  2018-05-29
# 9      110     John         HR       New York  59000.0  2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0  2019-02-20
# 11     112      Leo         IT         Boston  77000.0  2022-01-01
# 12     113     Mike  Marketing       New York  61000.0  2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0  2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0  2018-12-19
# 15     116     Paul         IT       New York  76000.0  2021-10-05
# 17     118   Rachel    Finance  San Francisco  71000.0  2020-04-17
# 18     119    Steve         HR        Chicago  60000.0  2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0  2018-08-28
#
#     performance_score
# 0                  88
# 1                  77
# 2                  91
# 3                  85
# 4                  92
# 6                  84
# 7                  88
# 8                  76
# 9                  79
# 10                 89
# 11                 95
# 12                 82
# 13                 80
# 14                 73
# 15                 90
# 17                 88
# 18                 81
# 19                 87

# %%
#check for data cleaning
df.isnull().sum()
# Out:
# emp_id               0
# name                 0
# department           0
# city                 0
# salary               2
# join_date            0
# performance_score    0
# dtype: int64

# %%
df.drop_duplicates() #Remove duplicate rows:
# Out:
#     emp_id     name department           city   salary   join_date  \
# 0      101    Alice         IT       New York  72000.0  2019-06-15
# 1      102      Bob         HR         Boston  58000.0  2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0  2018-01-10
# 3      104    David         IT         Boston  75000.0  2017-03-25
# 4      105      Eve    Finance       New York  69000.0  2021-07-11
# 5      106    Frank         IT        Chicago      NaN  2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0  2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0  2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0  2018-05-29
# 9      110     John         HR       New York  59000.0  2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0  2019-02-20
# 11     112      Leo         IT         Boston  77000.0  2022-01-01
# 12     113     Mike  Marketing       New York  61000.0  2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0  2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0  2018-12-19
# 15     116     Paul         IT       New York  76000.0  2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN  2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0  2020-04-17
# 18     119    Steve         HR        Chicago  60000.0  2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0  2018-08-28
#
#     performance_score
# 0                  88
# 1                  77
# 2                  91
# 3                  85
# 4                  92
# 5                  80
# 6                  84
# 7                  88
# 8                  76
# 9                  79
# 10                 89
# 11                 95
# 12                 82
# 13                 80
# 14                 73
# 15                 90
# 16                 85
# 17                 88
# 18                 81
# 19                 87

# %%
df.drop_duplicates()
# Out:
#     emp_id     name department           city   salary   join_date  \
# 0      101    Alice         IT       New York  72000.0  2019-06-15
# 1      102      Bob         HR         Boston  58000.0  2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0  2018-01-10
# 3      104    David         IT         Boston  75000.0  2017-03-25
# 4      105      Eve    Finance       New York  69000.0  2021-07-11
# 5      106    Frank         IT        Chicago      NaN  2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0  2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0  2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0  2018-05-29
# 9      110     John         HR       New York  59000.0  2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0  2019-02-20
# 11     112      Leo         IT         Boston  77000.0  2022-01-01
# 12     113     Mike  Marketing       New York  61000.0  2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0  2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0  2018-12-19
# 15     116     Paul         IT       New York  76000.0  2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN  2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0  2020-04-17
# 18     119    Steve         HR        Chicago  60000.0  2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0  2018-08-28
#
#     performance_score
# 0                  88
# 1                  77
# 2                  91
# 3                  85
# 4                  92
# 5                  80
# 6                  84
# 7                  88
# 8                  76
# 9                  79
# 10                 89
# 11                 95
# 12                 82
# 13                 80
# 14                 73
# 15                 90
# 16                 85
# 17                 88
# 18                 81
# 19                 87

# %%
df['join_date'] = pd.to_datetime(df['join_date'])

# %%
df.dtypes
# Out:
# emp_id                        int64
# name                         object
# department                   object
# city                         object
# salary                      float64
# join_date            datetime64[ns]
# performance_score             int64
# dtype: object

# %%
df['join_year'] = df['join_date'].dt.year
df['join_month'] = df['join_date'].dt.month

# %%
df
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 1      102      Bob         HR         Boston  58000.0 2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 4      105      Eve    Finance       New York  69000.0 2021-07-11
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0 2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 9      110     John         HR       New York  59000.0 2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 11     112      Leo         IT         Boston  77000.0 2022-01-01
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 15     116     Paul         IT       New York  76000.0 2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 18     119    Steve         HR        Chicago  60000.0 2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month
# 0                  88       2019           6
# 1                  77       2020           8
# 2                  91       2018           1
# 3                  85       2017           3
# 4                  92       2021           7
# 5                  80       2019          11
# 6                  84       2020          12
# 7                  88       2016          10
# 8                  76       2018           5
# 9                  79       2021           3
# 10                 89       2019           2
# 11                 95       2022           1
# 12                 82       2017           9
# 13                 80       2016           6
# 14                 73       2018          12
# 15                 90       2021          10
# 16                 85       2019           5
# 17                 88       2020           4
# 18                 81       2021           2
# 19                 87       2018           8

# %%
df[(df['department'] == 'IT') & (df['salary'] > 75000)]
# Out:
#     emp_id  name department      city   salary  join_date  performance_score  \
# 11     112   Leo         IT    Boston  77000.0 2022-01-01                 95
# 15     116  Paul         IT  New York  76000.0 2021-10-05                 90
#
#     join_year  join_month
# 11       2022           1
# 15       2021          10

# %%
df[df['join_date'] < '2020-01-01']
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month
# 0                  88       2019           6
# 2                  91       2018           1
# 3                  85       2017           3
# 5                  80       2019          11
# 7                  88       2016          10
# 8                  76       2018           5
# 10                 89       2019           2
# 12                 82       2017           9
# 13                 80       2016           6
# 14                 73       2018          12
# 16                 85       2019           5
# 19                 87       2018           8

# %%
df.sort_values(by='performance_score', ascending=False).head(5)
# Out:
#     emp_id     name department      city   salary  join_date  \
# 11     112      Leo         IT    Boston  77000.0 2022-01-01
# 4      105      Eve    Finance  New York  69000.0 2021-07-11
# 2      103  Charlie    Finance   Chicago  67000.0 2018-01-10
# 15     116     Paul         IT  New York  76000.0 2021-10-05
# 10     111     Kate    Finance   Chicago  73000.0 2019-02-20
#
#     performance_score  join_year  join_month
# 11                 95       2022           1
# 4                  92       2021           7
# 2                  91       2018           1
# 15                 90       2021          10
# 10                 89       2019           2

# %%
df[(df['department'] == 'Marketing') & (df['city'] == 'Boston')]
# Out:
#     emp_id   name department    city   salary  join_date  performance_score  \
# 8      109    Ivy  Marketing  Boston  60000.0 2018-05-29                 76
# 16     117  Quinn  Marketing  Boston      NaN 2019-05-30                 85
#
#     join_year  join_month
# 8        2018           5
# 16       2019           5

# %%
df[df['salary'].isna()]
# Out:
#     emp_id   name department     city  salary  join_date  performance_score  \
# 5      106  Frank         IT  Chicago     NaN 2019-11-04                 80
# 16     117  Quinn  Marketing   Boston     NaN 2019-05-30                 85
#
#     join_year  join_month
# 5        2019          11
# 16       2019           5

# %%
df.groupby('department')['salary'].mean().reset_index()
# Out:
#   department        salary
# 0    Finance  69600.000000
# 1         HR  59750.000000
# 2         IT  74333.333333
# 3  Marketing  60666.666667

# %%
df['city'].value_counts().reset_index().rename(columns={'index': 'city', 'city': 'employee_count'})
# Out:
#   employee_count  count
# 0       New York      5
# 1         Boston      5
# 2        Chicago      5
# 3  San Francisco      5

# %%
df.groupby('department')['performance_score'].max().reset_index()
# Out:
#   department  performance_score
# 0    Finance                 92
# 1         HR                 81
# 2         IT                 95
# 3  Marketing                 85

# %%
df[df['department'] == 'Finance']['salary'].sum()
# Out:
# np.float64(348000.0)

# %%
df['join_year'].value_counts().sort_index().reset_index().rename(
    columns={'index': 'join_year', 'join_year': 'employee_count'})
# Out:
#    employee_count  count
# 0            2016      2
# 1            2017      2
# 2            2018      4
# 3            2019      4
# 4            2020      3
# 5            2021      4
# 6            2022      1

# %%
departments_df = pd.read_csv('dept.csv')
departments_df
# Out:
#   department manager
# 0         IT   Aaron
# 1    Finance   Bruce
# 2         HR   Clara
# 3  Marketing   Derek

# %%
merged_df = df.merge(departments_df, on='department', how='left')
merged_df
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 1      102      Bob         HR         Boston  58000.0 2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 4      105      Eve    Finance       New York  69000.0 2021-07-11
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0 2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 9      110     John         HR       New York  59000.0 2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 11     112      Leo         IT         Boston  77000.0 2022-01-01
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 15     116     Paul         IT       New York  76000.0 2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 18     119    Steve         HR        Chicago  60000.0 2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month manager
# 0                  88       2019           6   Aaron
# 1                  77       2020           8   Clara
# 2                  91       2018           1   Bruce
# 3                  85       2017           3   Aaron
# 4                  92       2021           7   Bruce
# 5                  80       2019          11   Aaron
# 6                  84       2020          12   Derek
# 7                  88       2016          10   Aaron
# 8                  76       2018           5   Derek
# 9                  79       2021           3   Clara
# 10                 89       2019           2   Bruce
# 11                 95       2022           1   Aaron
# 12                 82       2017           9   Derek
# 13                 80       2016           6   Clara
# 14                 73       2018          12   Bruce
# 15                 90       2021          10   Aaron
# 16                 85       2019           5   Derek
# 17                 88       2020           4   Bruce
# 18                 81       2021           2   Clara
# 19                 87       2018           8   Aaron

# %%
merged_df[merged_df['department'] == 'Marketing']
# Out:
#     emp_id   name department           city   salary  join_date  \
# 6      107  Grace  Marketing  San Francisco  61000.0 2020-12-23
# 8      109    Ivy  Marketing         Boston  60000.0 2018-05-29
# 12     113   Mike  Marketing       New York  61000.0 2017-09-15
# 16     117  Quinn  Marketing         Boston      NaN 2019-05-30
#
#     performance_score  join_year  join_month manager
# 6                  84       2020          12   Derek
# 8                  76       2018           5   Derek
# 12                 82       2017           9   Derek
# 16                 85       2019           5   Derek

# %%
df['rank'] = df.groupby('department')['performance_score'].rank(ascending=False)
df
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 1      102      Bob         HR         Boston  58000.0 2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 4      105      Eve    Finance       New York  69000.0 2021-07-11
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0 2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 9      110     John         HR       New York  59000.0 2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 11     112      Leo         IT         Boston  77000.0 2022-01-01
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 15     116     Paul         IT       New York  76000.0 2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 18     119    Steve         HR        Chicago  60000.0 2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month  rank
# 0                  88       2019           6   3.5
# 1                  77       2020           8   4.0
# 2                  91       2018           1   2.0
# 3                  85       2017           3   6.0
# 4                  92       2021           7   1.0
# 5                  80       2019          11   7.0
# 6                  84       2020          12   2.0
# 7                  88       2016          10   3.5
# 8                  76       2018           5   4.0
# 9                  79       2021           3   3.0
# 10                 89       2019           2   3.0
# 11                 95       2022           1   1.0
# 12                 82       2017           9   3.0
# 13                 80       2016           6   2.0
# 14                 73       2018          12   5.0
# 15                 90       2021          10   2.0
# 16                 85       2019           5   1.0
# 17                 88       2020           4   4.0
# 18                 81       2021           2   1.0
# 19                 87       2018           8   5.0

# %%
df['cumulative_salary'] = df.sort_values('join_date') \
    .groupby('department')['salary'].cumsum()
df
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 1      102      Bob         HR         Boston  58000.0 2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 4      105      Eve    Finance       New York  69000.0 2021-07-11
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0 2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 9      110     John         HR       New York  59000.0 2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 11     112      Leo         IT         Boston  77000.0 2022-01-01
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 15     116     Paul         IT       New York  76000.0 2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 18     119    Steve         HR        Chicago  60000.0 2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month  rank  cumulative_salary
# 0                  88       2019           6   3.5           293000.0
# 1                  77       2020           8   4.0           120000.0
# 2                  91       2018           1   2.0            67000.0
# 3                  85       2017           3   6.0           149000.0
# 4                  92       2021           7   1.0           348000.0
# 5                  80       2019          11   7.0                NaN
# 6                  84       2020          12   2.0           182000.0
# 7                  88       2016          10   3.5            74000.0
# 8                  76       2018           5   4.0           121000.0
# 9                  79       2021           3   3.0           239000.0
# 10                 89       2019           2   3.0           208000.0
# 11                 95       2022           1   1.0           446000.0
# 12                 82       2017           9   3.0            61000.0
# 13                 80       2016           6   2.0            62000.0
# 14                 73       2018          12   5.0           135000.0
# 15                 90       2021          10   2.0           369000.0
# 16                 85       2019           5   1.0                NaN
# 17                 88       2020           4   4.0           279000.0
# 18                 81       2021           2   1.0           180000.0
# 19                 87       2018           8   5.0           221000.0

# %%
top_earners = df.loc[df.groupby('department')['salary'].idxmax()]
top_earners
# Out:
#     emp_id   name department           city   salary  join_date  \
# 10     111   Kate    Finance        Chicago  73000.0 2019-02-20
# 13     114   Nina         HR  San Francisco  62000.0 2016-06-22
# 11     112    Leo         IT         Boston  77000.0 2022-01-01
# 6      107  Grace  Marketing  San Francisco  61000.0 2020-12-23
#
#     performance_score  join_year  join_month  rank  cumulative_salary
# 10                 89       2019           2   3.0           208000.0
# 13                 80       2016           6   2.0            62000.0
# 11                 95       2022           1   1.0           446000.0
# 6                  84       2020          12   2.0           182000.0

# %%
pd.pivot_table(df, values='salary', index='city', columns='department', aggfunc='mean')
# Out:
# department          Finance       HR       IT  Marketing
# city
# Boston                  NaN  58000.0  76000.0    60000.0
# Chicago        69333.333333  60000.0      NaN        NaN
# New York       69000.000000  59000.0  74000.0    61000.0
# San Francisco  71000.000000  62000.0  73000.0    61000.0

# %%
pd.melt(df, id_vars=['emp_id', 'department'], value_vars=['salary', 'performance_score'])
# Out:
#     emp_id department           variable    value
# 0      101         IT             salary  72000.0
# 1      102         HR             salary  58000.0
# 2      103    Finance             salary  67000.0
# 3      104         IT             salary  75000.0
# 4      105    Finance             salary  69000.0
# 5      106         IT             salary      NaN
# 6      107  Marketing             salary  61000.0
# 7      108         IT             salary  74000.0
# 8      109  Marketing             salary  60000.0
# 9      110         HR             salary  59000.0
# 10     111    Finance             salary  73000.0
# 11     112         IT             salary  77000.0
# 12     113  Marketing             salary  61000.0
# 13     114         HR             salary  62000.0
# 14     115    Finance             salary  68000.0
# 15     116         IT             salary  76000.0
# 16     117  Marketing             salary      NaN
# 17     118    Finance             salary  71000.0
# 18     119         HR             salary  60000.0
# 19     120         IT             salary  72000.0
# 20     101         IT  performance_score     88.0
# 21     102         HR  performance_score     77.0
# 22     103    Finance  performance_score     91.0
# 23     104         IT  performance_score     85.0
# 24     105    Finance  performance_score     92.0
# 25     106         IT  performance_score     80.0
# 26     107  Marketing  performance_score     84.0
# 27     108         IT  performance_score     88.0
# 28     109  Marketing  performance_score     76.0
# 29     110         HR  performance_score     79.0
# 30     111    Finance  performance_score     89.0
# 31     112         IT  performance_score     95.0
# 32     113  Marketing  performance_score     82.0
# 33     114         HR  performance_score     80.0
# 34     115    Finance  performance_score     73.0
# 35     116         IT  performance_score     90.0
# 36     117  Marketing  performance_score     85.0
# 37     118    Finance  performance_score     88.0
# 38     119         HR  performance_score     81.0
# 39     120         IT  performance_score     87.0

# %%
df['tenure_days'] = (pd.to_datetime('today') - df['join_date']).dt.days
df
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 1      102      Bob         HR         Boston  58000.0 2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 4      105      Eve    Finance       New York  69000.0 2021-07-11
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0 2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 9      110     John         HR       New York  59000.0 2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 11     112      Leo         IT         Boston  77000.0 2022-01-01
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 15     116     Paul         IT       New York  76000.0 2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 18     119    Steve         HR        Chicago  60000.0 2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month  rank  cumulative_salary  \
# 0                  88       2019           6   3.5           293000.0
# 1                  77       2020           8   4.0           120000.0
# 2                  91       2018           1   2.0            67000.0
# 3                  85       2017           3   6.0           149000.0
# 4                  92       2021           7   1.0           348000.0
# 5                  80       2019          11   7.0                NaN
# 6                  84       2020          12   2.0           182000.0
# 7                  88       2016          10   3.5            74000.0
# 8                  76       2018           5   4.0           121000.0
# 9                  79       2021           3   3.0           239000.0
# 10                 89       2019           2   3.0           208000.0
# 11                 95       2022           1   1.0           446000.0
# 12                 82       2017           9   3.0            61000.0
# 13                 80       2016           6   2.0            62000.0
# 14                 73       2018          12   5.0           135000.0
# 15                 90       2021          10   2.0           369000.0
# 16                 85       2019           5   1.0                NaN
# 17                 88       2020           4   4.0           279000.0
# 18                 81       2021           2   1.0           180000.0
# 19                 87       2018           8   5.0           221000.0
#
#     tenure_days
# 0          2232
# 1          1819
# 2          2753
# 3          3044
# 4          1475
# 5          2090
# 6          1675
# 7          3202
# 8          2614
# 9          1595
# 10         2347
# 11         1301
# 12         2870
# 13         3320
# 14         2410
# 15         1389
# 16         2248
# 17         1925
# 18         1626
# 19         2523

# %%
df['join_quarter'] = df['join_date'].dt.to_period('Q')
df['join_quarter'].value_counts().sort_index()
df
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 1      102      Bob         HR         Boston  58000.0 2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 4      105      Eve    Finance       New York  69000.0 2021-07-11
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0 2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 9      110     John         HR       New York  59000.0 2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 11     112      Leo         IT         Boston  77000.0 2022-01-01
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 15     116     Paul         IT       New York  76000.0 2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 18     119    Steve         HR        Chicago  60000.0 2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month  rank  cumulative_salary  \
# 0                  88       2019           6   3.5           293000.0
# 1                  77       2020           8   4.0           120000.0
# 2                  91       2018           1   2.0            67000.0
# 3                  85       2017           3   6.0           149000.0
# 4                  92       2021           7   1.0           348000.0
# 5                  80       2019          11   7.0                NaN
# 6                  84       2020          12   2.0           182000.0
# 7                  88       2016          10   3.5            74000.0
# 8                  76       2018           5   4.0           121000.0
# 9                  79       2021           3   3.0           239000.0
# 10                 89       2019           2   3.0           208000.0
# 11                 95       2022           1   1.0           446000.0
# 12                 82       2017           9   3.0            61000.0
# 13                 80       2016           6   2.0            62000.0
# 14                 73       2018          12   5.0           135000.0
# 15                 90       2021          10   2.0           369000.0
# 16                 85       2019           5   1.0                NaN
# 17                 88       2020           4   4.0           279000.0
# 18                 81       2021           2   1.0           180000.0
# 19                 87       2018           8   5.0           221000.0
#
#     tenure_days join_quarter
# 0          2232       2019Q2
# 1          1819       2020Q3
# 2          2753       2018Q1
# 3          3044       2017Q1
# 4          1475       2021Q3
# 5          2090       2019Q4
# 6          1675       2020Q4
# 7          3202       2016Q4
# 8          2614       2018Q2
# 9          1595       2021Q1
# 10         2347       2019Q1
# 11         1301       2022Q1
# 12         2870       2017Q3
# 13         3320       2016Q2
# 14         2410       2018Q4
# 15         1389       2021Q4
# 16         2248       2019Q2
# 17         1925       2020Q2
# 18         1626       2021Q1
# 19         2523       2018Q3

# %%
fifty_months_ago = pd.to_datetime('today') - pd.DateOffset(months=50)
df[df['join_date'] >= fifty_months_ago]
# Out:
#     emp_id  name department      city   salary  join_date  performance_score  \
# 4      105   Eve    Finance  New York  69000.0 2021-07-11                 92
# 11     112   Leo         IT    Boston  77000.0 2022-01-01                 95
# 15     116  Paul         IT  New York  76000.0 2021-10-05                 90
#
#     join_year  join_month  rank  cumulative_salary  tenure_days join_quarter
# 4        2021           7   1.0           348000.0         1475       2021Q3
# 11       2022           1   1.0           446000.0         1301       2022Q1
# 15       2021          10   2.0           369000.0         1389       2021Q4

# %%
df['years_with_company'] = (pd.to_datetime('today') - df['join_date']).dt.days // 365
df
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 1      102      Bob         HR         Boston  58000.0 2020-08-01
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 4      105      Eve    Finance       New York  69000.0 2021-07-11
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 6      107    Grace  Marketing  San Francisco  61000.0 2020-12-23
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 9      110     John         HR       New York  59000.0 2021-03-13
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 11     112      Leo         IT         Boston  77000.0 2022-01-01
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 15     116     Paul         IT       New York  76000.0 2021-10-05
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 18     119    Steve         HR        Chicago  60000.0 2021-02-10
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month  rank  cumulative_salary  \
# 0                  88       2019           6   3.5           293000.0
# 1                  77       2020           8   4.0           120000.0
# 2                  91       2018           1   2.0            67000.0
# 3                  85       2017           3   6.0           149000.0
# 4                  92       2021           7   1.0           348000.0
# 5                  80       2019          11   7.0                NaN
# 6                  84       2020          12   2.0           182000.0
# 7                  88       2016          10   3.5            74000.0
# 8                  76       2018           5   4.0           121000.0
# 9                  79       2021           3   3.0           239000.0
# 10                 89       2019           2   3.0           208000.0
# 11                 95       2022           1   1.0           446000.0
# 12                 82       2017           9   3.0            61000.0
# 13                 80       2016           6   2.0            62000.0
# 14                 73       2018          12   5.0           135000.0
# 15                 90       2021          10   2.0           369000.0
# 16                 85       2019           5   1.0                NaN
# 17                 88       2020           4   4.0           279000.0
# 18                 81       2021           2   1.0           180000.0
# 19                 87       2018           8   5.0           221000.0
#
#     tenure_days join_quarter  years_with_company
# 0          2232       2019Q2                   6
# 1          1819       2020Q3                   4
# 2          2753       2018Q1                   7
# 3          3044       2017Q1                   8
# 4          1475       2021Q3                   4
# 5          2090       2019Q4                   5
# 6          1675       2020Q4                   4
# 7          3202       2016Q4                   8
# 8          2614       2018Q2                   7
# 9          1595       2021Q1                   4
# 10         2347       2019Q1                   6
# 11         1301       2022Q1                   3
# 12         2870       2017Q3                   7
# 13         3320       2016Q2                   9
# 14         2410       2018Q4                   6
# 15         1389       2021Q4                   3
# 16         2248       2019Q2                   6
# 17         1925       2020Q2                   5
# 18         1626       2021Q1                   4
# 19         2523       2018Q3                   6

# %%
df[df['years_with_company'] >= 5]
# Out:
#     emp_id     name department           city   salary  join_date  \
# 0      101    Alice         IT       New York  72000.0 2019-06-15
# 2      103  Charlie    Finance        Chicago  67000.0 2018-01-10
# 3      104    David         IT         Boston  75000.0 2017-03-25
# 5      106    Frank         IT        Chicago      NaN 2019-11-04
# 7      108    Heidi         IT  San Francisco  74000.0 2016-10-18
# 8      109      Ivy  Marketing         Boston  60000.0 2018-05-29
# 10     111     Kate    Finance        Chicago  73000.0 2019-02-20
# 12     113     Mike  Marketing       New York  61000.0 2017-09-15
# 13     114     Nina         HR  San Francisco  62000.0 2016-06-22
# 14     115     Owen    Finance        Chicago  68000.0 2018-12-19
# 16     117    Quinn  Marketing         Boston      NaN 2019-05-30
# 17     118   Rachel    Finance  San Francisco  71000.0 2020-04-17
# 19     120     Tina         IT  San Francisco  72000.0 2018-08-28
#
#     performance_score  join_year  join_month  rank  cumulative_salary  \
# 0                  88       2019           6   3.5           293000.0
# 2                  91       2018           1   2.0            67000.0
# 3                  85       2017           3   6.0           149000.0
# 5                  80       2019          11   7.0                NaN
# 7                  88       2016          10   3.5            74000.0
# 8                  76       2018           5   4.0           121000.0
# 10                 89       2019           2   3.0           208000.0
# 12                 82       2017           9   3.0            61000.0
# 13                 80       2016           6   2.0            62000.0
# 14                 73       2018          12   5.0           135000.0
# 16                 85       2019           5   1.0                NaN
# 17                 88       2020           4   4.0           279000.0
# 19                 87       2018           8   5.0           221000.0
#
#     tenure_days join_quarter  years_with_company
# 0          2232       2019Q2                   6
# 2          2753       2018Q1                   7
# 3          3044       2017Q1                   8
# 5          2090       2019Q4                   5
# 7          3202       2016Q4                   8
# 8          2614       2018Q2                   7
# 10         2347       2019Q1                   6
# 12         2870       2017Q3                   7
# 13         3320       2016Q2                   9
# 14         2410       2018Q4                   6
# 16         2248       2019Q2                   6
# 17         1925       2020Q2                   5
# 19         2523       2018Q3                   6
